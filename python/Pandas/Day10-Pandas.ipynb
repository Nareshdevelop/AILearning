# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('C:\\Users\\akhil\\OneDrive\\Desktop\\AI Class\\python\\Pandas\\titanic.csv')

# %%
df['Survived'].count()
# Out:
# np.int64(891)

# %%
df['Survived'].unique()
# Out:
# array([0, 1])

# %%
df['Survived'].value_counts()
# Out:
# Survived
# 0    549
# 1    342
# Name: count, dtype: int64

# %%
# finding statistical data for each column
df['Survived'].mean()
# Out:
# np.float64(0.3838383838383838)

# %%
df['Survived'].mode()
# Out:
# 0    0
# Name: Survived, dtype: int64

# %%
df['Survived'].describe()
# Out:
# count    891.000000
# mean       0.383838
# std        0.486592
# min        0.000000
# 25%        0.000000
# 50%        0.000000
# 75%        1.000000
# max        1.000000
# Name: Survived, dtype: float64

# %%
df[['PassengerId', 'Survived','Pclass']].dtypes
# Out:
# PassengerId    int64
# Survived       int64
# Pclass         int64
# dtype: object

# %%
df.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
df[['SibSp','Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked']].dtypes
# Out:
# SibSp         int64
# Parch         int64
# Ticket       object
# Fare        float64
# Cabin        object
# Embarked     object
# dtype: object

# %%
df[['SibSp','Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked']].describe()
# Out:
#             SibSp       Parch        Fare
# count  891.000000  891.000000  891.000000
# mean     0.523008    0.381594   32.204208
# std      1.102743    0.806057   49.693429
# min      0.000000    0.000000    0.000000
# 25%      0.000000    0.000000    7.910400
# 50%      0.000000    0.000000   14.454200
# 75%      1.000000    0.000000   31.000000
# max      8.000000    6.000000  512.329200

# %%
# trying to find data from rows i want and coumns i want.
df.iloc[150:200,3:]
# Out:
#                                                   Name     Sex   Age  SibSp  \
# 150                         Bateman, Rev. Robert James    male  51.0      0
# 151                  Pears, Mrs. Thomas (Edith Wearne)  female  22.0      1
# 152                                   Meo, Mr. Alfonzo    male  55.5      0
# 153                    van Billiard, Mr. Austin Blyler    male  40.5      0
# 154                              Olsen, Mr. Ole Martin    male   NaN      0
# 155                        Williams, Mr. Charles Duane    male  51.0      0
# 156                   Gilnagh, Miss. Katherine "Katie"  female  16.0      0
# 157                                    Corn, Mr. Harry    male  30.0      0
# 158                                Smiljanic, Mr. Mile    male   NaN      0
# 159                         Sage, Master. Thomas Henry    male   NaN      8
# 160                           Cribb, Mr. John Hatfield    male  44.0      0
# ...

# %%
df.loc[100:200, 'PassengerId':'Pclass']
# Out:
#      PassengerId  Survived  Pclass
# 100          101         0       3
# 101          102         0       3
# 102          103         0       1
# 103          104         0       3
# 104          105         0       3
# ..           ...       ...     ...
# 196          197         0       3
# 197          198         0       3
# 198          199         1       3
# 199          200         0       2
# 200          201         0       3
#
# [101 rows x 3 columns]

# %%
# viewing data about each column. find missing columns in each column
df['Age'].isnull().sum()
# Out:
# np.int64(177)

# %%
# Viewing rows that has missing values 
df[df['Age'].isnull()]
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 5              6         0       3                          Moran, Mr. James
# 17            18         1       2              Williams, Mr. Charles Eugene
# 19            20         1       3                   Masselmani, Mrs. Fatima
# 26            27         0       3                   Emir, Mr. Farred Chehab
# 28            29         1       3             O'Dwyer, Miss. Ellen "Nellie"
# ..           ...       ...     ...                                       ...
# 859          860         0       3                          Razi, Mr. Raihed
# 863          864         0       3         Sage, Miss. Dorothy Edith "Dolly"
# 868          869         0       3               van Melkebeke, Mr. Philemon
# 878          879         0       3                        Laleff, Mr. Kristo
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
#
# ...

# %%
# finding duplicate rows or values in each column 
df['Age'].duplicated().sum()
# Out:
# np.int64(802)

# %%
df['Age'].value_counts()
# Out:
# Age
# 24.00    30
# 22.00    27
# 18.00    26
# 28.00    25
# 30.00    25
#          ..
# 24.50     1
# 0.67      1
# 0.42      1
# 34.50     1
# 74.00     1
# Name: count, Length: 88, dtype: int64

# %%
df.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
# check for only rows for whose age is above 54

df[df['Age']>54].count()
# Out:
# PassengerId    42
# Survived       42
# Pclass         42
# Name           42
# Sex            42
# Age            42
# SibSp          42
# Parch          42
# Ticket         42
# Fare           42
# Cabin          23
# Embarked       41
# dtype: int64

# %%
# finding rows of count whose age is above 54 band ,male gender
df[(df['Age']>54) & (df['Sex']=='male')]
# Out:
#      PassengerId  Survived  Pclass                                  Name  \
# 33            34         0       2                 Wheadon, Mr. Edward H
# 54            55         0       1        Ostby, Mr. Engelhart Cornelius
# 94            95         0       3                     Coxon, Mr. Daniel
# 96            97         0       1             Goldschmidt, Mr. George B
# 116          117         0       3                  Connors, Mr. Patrick
# 152          153         0       3                      Meo, Mr. Alfonzo
# 170          171         0       1             Van der hoef, Mr. Wyckoff
# 174          175         0       1               Smith, Mr. James Clinch
# 232          233         0       2             Sjostedt, Mr. Ernst Adolf
# 252          253         0       1             Stead, Mr. William Thomas
# 280          281         0       3                      Duane, Mr. Frank
# 326          327         0       3             Nysveen, Mr. Johan Hansen
# ...

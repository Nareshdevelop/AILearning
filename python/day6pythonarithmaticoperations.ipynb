# %%
print("Hello")
# Out:
# Hello

# %%
2 + 3
# Out:
# 5

# %%
2 -3
# Out:
# -1

# %%
2*3
# Out:
# 6

# %%
2 ** 4
# Out:
# 16

# %%
2/3
# Out:
# 0.6666666666666666

# %% [markdown]
# BODMAS (Bracket Open, Division, Multiplication, Addition, Substraction)

# %%
# Modulus Operator Mod Operator  %
8 % 4
# Out:
# 0

# %%
# working with comparison operators in Python

# %%
# working with conditional statements in Python
#1 If
  # if else
        # if - elif - else 
#2For
#3 while

# %%
if(condition):
    #code to be executed if condition is true
    print("Condition is True")
else:
    #code to be executed if condition is false
    print("Condition is False")
